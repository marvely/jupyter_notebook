# %%
import numpy as np
import seaborn as sns
import pandas as pd
# %matplotlib inline

# %%
df1 = pd.read_csv('df1', index_col = 0)

# %%
df1.info() # <-- the index is time series
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1000 entries, 2000-01-01 to 2002-09-26
# Data columns (total 4 columns):
# A    1000 non-null float64
# B    1000 non-null float64
# C    1000 non-null float64
# D    1000 non-null float64
# dtypes: float64(4)
# memory usage: 39.1+ KB

# %%
df1.head()
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436

# %%
df2 = pd.read_csv('df2')

# %%
df2.head()
# Out:
#           a         b         c         d
# 0  0.039762  0.218517  0.103423  0.957904
# 1  0.937288  0.041567  0.899125  0.977680
# 2  0.780504  0.008948  0.557808  0.797510
# 3  0.672717  0.247870  0.264071  0.444358
# 4  0.053829  0.520124  0.552264  0.190008

# %%
df1['A'].hist() # <-- look nicer~ with seaborn imported

# %%
df1['A'].plot.hist()

# %%
df2.plot.area(alpha = 0.5)

# %%
df2.plot.bar(stacked = True) #<-- take the index value as categorical value.

# %%
df1.plot.line(x = df1.index, y = 'B', figsize = (10, 3), lw = 0.4)

# %%
df1.plot.scatter(x = 'A', y = 'B', c = 'C', cmap = 'coolwarm') # <--- 3 dimensional information

# %%
df1.plot.scatter(x = 'A', y = 'B', s = df1['C']*100) # <--- 3 dimensional information

# %%
df2.plot.box()

# %%
df = pd.DataFrame(np.random.randn(1000, 2), columns = ['a', 'b'])

# %%
df.head()
# Out:
#           a         b
# 0  1.033384  1.578264
# 1 -1.155368 -0.030920
# 2 -0.709085 -0.833082
# 3 -0.523524 -0.023590
# 4  0.704256  0.027379

# %%
df.plot.hexbin(x = 'a', y = 'b', gridsize = 25, cmap = 'coolwarm')

# %% [markdown]
# ## kernal density estimation plot

# %%
df2['a'].plot.kde()

# %%
df2['a'].plot.density()
